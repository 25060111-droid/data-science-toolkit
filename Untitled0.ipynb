# %% [markdown]
# <a href="https://colab.research.google.com/github/25060111-droid/data-science-toolkit/blob/Tutorial-3/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
array_2x2 = np.array([[1, 2],[3, 4]])
print("1. Numpy array of size 2x2:\n", array_2x2)
# Out:
# 1. Numpy array of size 2x2:
#  [[1 2]
#  [3 4]]

# %%
import numpy as np
random_3x4 = np.random.rand(3, 4)
print("\n2. Random numpy array of size 3x4:\n", random_3x4)
# Out:
# 2. Random numpy array of size 3x4:
#  [[0.10041876 0.39565431 0.5126277  0.18819069]
#  [0.59017111 0.48049921 0.73122642 0.92211495]
#  [0.40131581 0.6704467  0.14388846 0.07734705]]

# %%
import numpy as np
ones_array = np.ones((2, 3))
zeroes_array = np.zeros((3, 2))
print("\n3.Numpy array of ones (2x3):\n", ones_array, "\n")
print("  Numpy array of zeroes (3x2):\n", zeroes_array)
# Out:
# 3.Numpy array of ones (2x3):
#  [[1. 1. 1.]
#  [1. 1. 1.]]
#
#   Numpy array of zeroes (3x2):
#  [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
import numpy as np
random_6x3 = np.random.rand(6, 3)
transpose_6x3 = random_6x3.T
print("\n4.Random numpy array of size 6x3:\n", random_6x3, "\n")
print("  Transposed array (3x6):\n", transpose_6x3)
# Out:
# 4.Random numpy array of size 6x3:
#  [[0.35220144 0.48233574 0.69041903]
#  [0.80104624 0.30834411 0.415041  ]
#  [0.7780825  0.61944941 0.72854664]
#  [0.62579399 0.61636023 0.20035373]
#  [0.81549811 0.85730206 0.22669629]
#  [0.36640233 0.530468   0.70272785]]
#
#   Transposed array (3x6):
#  [[0.35220144 0.80104624 0.7780825  0.62579399 0.81549811 0.36640233]
#  [0.48233574 0.30834411 0.61944941 0.61636023 0.85730206 0.530468  ]
#  [0.69041903 0.415041   0.72854664 0.20035373 0.22669629 0.70272785]]

# %%
import numpy as np
n, p, m = 2, 3, 4
A = np.random.rand(n, p)
B = np.random.rand(p, m)
dot_product = np.dot(A, B)
print("\n5. Matrix A ({}x{}):\n".format(n, p), A, "\n")
print("   Matrix B ({}x{}):\n".format(p, m), B , "\n")
print("   Dot product ({}x{}):\n".format(n, m), dot_product)
# Out:
# 5. Matrix A (2x3):
#  [[0.96516978 0.28432861 0.78629923]
#  [0.34987871 0.18054464 0.36428922]]
#
#    Matrix B (3x4):
#  [[0.26358473 0.96286002 0.69501015 0.54804444]
#  [0.54732675 0.16636066 0.3208013  0.812203  ]
#  [0.18113647 0.37067808 0.82975456 0.50852961]]
#
#    Dot product (2x4):
#  [[0.55245214 1.26808838 1.41445115 1.15974493]
#  [0.25702566 0.50195378 0.60335885 0.52363984]]
